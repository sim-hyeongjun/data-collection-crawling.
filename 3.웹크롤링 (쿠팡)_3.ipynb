# %% [markdown]
# ### 지마켓 베스트 페이지 상품명 가격 + 이중 크로링으로 배송사 알아내기

# %%
import requests
from bs4 import BeautifulSoup
import re

res = requests.get('http://corners.gmarket.co.kr/Bestsellers?viewType=G&groupCode=G06')
soup = BeautifulSoup(res.content, 'html.parser')
bestlists = soup.select('div.best-list')
bestitems=bestlists[0]                     #혹시 html에 동일한 div가 있을수도 있기때문에  몀ㅊ번째 div인지 지정
bestitem = bestitems.select('ul > li')


for index,item in enumerate(bestitem):
    p_name= item.select_one('a.itemname')
    p_price= item.select_one('div.s-price> strong')


    delivery_info=requests.get(p_name['href'])
    soup_info = BeautifulSoup(delivery_info.content, 'html.parser')
    gets= soup_info.select_one('p > span.text__seller>a')


    print(p_name.get_text(),p_price.get_text(),gets.get_text())
# Out:
# [어메이즈핏]GTS4 mini 스마트워치 국내 정식 발매 한글판 95,550원 엠큐디지털
# [필립스](최종1.3만원대)PHILIPS 보풀제거기 GC026/00 16,750원 필립스생활가전코리아
# [에어팟]에어팟 3세대 Magsafe MME73KH/A 232,000원 Apple공식판매점
# [애플](사전예약) Apple 2022 에어팟 프로 2세대 MQD83KH/A 330,280원 Apple공식판매점
# [일월]22년모델일월 마이크로 카본 온열매트 싱글 63,200원 GSSHOPTV
# [HP]14-ec0032AU 파빌리온 신제품 대학생 노트북 689,000원 HP공식판매점
# [BANADA]삼성 호환 C타입 고속충전 케이블 5개입 (150cm) 7,500원 스마일배송
# [그랑데]삼성 그랑데 건조기 DV17T8520BP 17kg 1등급 이녹스실버 995,000원 삼성하나로
# [신일전자]신일 2단 미니 히터/스토브/미니난로 SEH-W30K 23,900원 스마일배송
# [제이엠더블유]JMW M5001A PLUS BLDC 드라이기  +사은품 (거치대 세트 스타벅스) 76,900원 스마일배송
# [신지모루]2매 핸드폰 강화유리 액정보호필름 아이폰 갤럭시 6,900원 신지모루
# [일월]일월 에어로실버 카본매트 싱글사이즈 본사직영몰 118,000원 주식회사일월
# [삼성전자]삼성전자 DDR4 16G PC4-25600 (정품) -MK 70,350원 명성마켓
# [일월]일월 에어로실버 카본매트 더블사이즈 본사직영몰 125,000원 주식회사일월
# 윤남텍 간편세척 초음파 다목적 가습기/YN-101/G마켓 82,000원 윤남텍
# [닌텐도]포켓몬스터바이올렛 예약판매 (게임 내 의상 아이템 및 오리지널 포켓몬 키홀더 선착순 증정) 59,800원 대원미디어(주)
# [한일의료기]그레이웨이브 EMF 탄소 전기요 전기장판 더블(대) 45,900원 스마일배송
# [한일의료기]그레이웨이브 EMF 탄소 전기요 전기장판 싱글(중) 39,900원 스마일배송
# ...

# %%
bestlists
# Out:
# [<div aria-label="베스트 상품 리스트" class="best-list" role="region">
#  <ul>
#  <li class="first">
#  <p class="no1" id="no1">1</p>
#  <div class="thumb">
#  <a href="http://item.gmarket.co.kr/Item?goodscode=2523198871&amp;ver=638016181965870280" onclick="pdsClickLog('200000680', 'Item', {'ASN': 1, 'goodsCode': '2523198871'});"><img alt="[어메이즈핏]GTS4 mini 스마트워치 국내 정식 발매 한글판" class="lazy" data-original="//gdimg.gmarket.co.kr/2523198871/still/300?ver=2022101715" height="210" src="//image.gmarket.co.kr/challenge/neo_image/no_image.gif" width="210"/></a>
#  </div>
#  <!--div class="goods-view">
#  									<a href="http://minishop.gmarket.co.kr/mqdigital2"><span class="view">판매자 다른상품 보기</span>엠큐디지털</a>
#  								</div-->
#  <a class="itemname" href="http://item.gmarket.co.kr/Item?goodscode=2523198871&amp;ver=638016181965870280" onclick="pdsClickLog('200000680', 'Item', {'ASN': 1, 'goodsCode': '2523198871'});">[어메이즈핏]GTS4 mini 스마트워치 국내 정식 발매 한글판</a>
#  <div class="item_price">
# ...

# %% [markdown]
# ### 지마켓 베스트 페이지 상품명 가격

# %%
import requests
from bs4 import BeautifulSoup
import re
res = requests.get('http://corners.gmarket.co.kr/Bestsellers?viewType=G&groupCode=G06')

soup=BeautifulSoup(res.content, 'html.parser')
bestlists=soup.select('div.best-list')
bestitmes= bestlists[0]
bestitem= bestitmes.select('ul> li')

for item in bestitem:
    name= item.select_one('a.itemname')
    price= item.select_one('div.s-price > strong')
    print(name.get_text(), price.get_text())
# Out:
# [큐씨와이]블루투스 무선 이어폰 T13 21년7월 최신 1+1 38,300원
# [로보락]로보락 S7 MaxV Ultra 로봇청소기 울트라 자동세척 + 열풍건조모듈 증정 1,589,000원
# [큐씨와이]1+1 QCY T13 블루투스 무선 이어폰   2021최신형 37,700원
# [아이닉](최종 14.5만)차이슨 무선청소기 i20 UV브러시탑재 199,000원
# [테팔]테팔 미니블렌더 믹스 앤 드링크 화이트 BL1301 34,500원
# [갤럭시북2]갤럭시북2 NT550XEZ-A58A 최종59만 인텔12세대 대학생추천 인강용 교육용 사무용 737,000원
# [로보락]로보락 S7 Plus 플러스 로봇청소기 947,000원
# [제이엠더블유]JMW M5001A PLUS BLDC 드라이기  +사은품 (거치대 세트 스타벅스) 78,000원
# 메르비 피부관리기기 고객요청 패키지 [마스크팩1박스 + 비타민C앰플]    199,750원
# [현대오피스]A3코팅기 PL-503 가정용 소형 코팅기계 자동절전  90초빠른예열 화이트 코팅지50매+재단기+라운더 60,900원
# [아이닉](최종 12.5만)대용량 스텐 에어프라이어 16L 화이트 179,000원
# [아이닉](최종 11.6만)아이닉 차이슨 무선청소기 i20 엘리트 159,000원
# [소니]PS5 듀얼센스 무선 컨트롤러 미드나이트 블랙 72,680원
# [일렉트로룩스](최초가 369000원) 18V 무선청소기 ZB3411 + 4종 노즐 사은품 증정 211,250원
# [어드밴스원]모니터 특가 61cm AF-2410UX 16:10비율 보더리스 광시야각 무결점 105,000원
# [갤럭시]삼성 갤럭시S22/S22플러스/S22울트라 자급제폰 SM-S90 CU 5000원권 3매 929,910원
# [아이닉]무선청소기 i20 전용 물걸레 키트 39,000원
# [쿠쿠](혜택가 206080원) 쿠쿠 본사직영 CRP-ST0610FW 6인용 트윈프레셔 밥솥 264,000원
# ...

# %% [markdown]
# #### 지마켓 베스트 페이지 상품명 가격 + 이중 크로링으로 배송사 알아내기

# %%
import requests
from bs4 import BeautifulSoup
import re

res = requests.get('http://corners.gmarket.co.kr/Bestsellers?viewType=G&groupCode=G06')
soup = BeautifulSoup(res.content, 'html.parser')
bestlists = soup.select('div.best-list')
bestitems=bestlists[0]                     #혹시 html에 동일한 div가 있을수도 있기때문에  몀ㅊ번째 div인지 지정
bestitem = bestitems.select('ul > li')


for index,item in enumerate(bestitem):
    p_name= item.select_one('a.itemname')
    p_price= item.select_one('div.s-price> strong')


    delivery_info=requests.get(p_name['href'])
    soup_info = BeautifulSoup(delivery_info.content, 'html.parser')
    gets= soup_info.select_one('p > span.text__seller>a')


    print(p_name.get_text(),p_price.get_text(),gets.get_text())
# Out:
# [레노버]최종가:171,300원 레노버 T1SPRO 클린스테이션 청소기 유럽버전 202,000원 직구플리즈
# [갤럭시]갤럭시S22 5G 256GB 자급제 SM-S901N 930,150원 삼성모바일공식스토어
# [유파]내일도착유파 선풍기리모컨초미풍발터치 TSK-3528CR 29,900원 CJ온스타일
# [르젠]르젠 리모컨 써큘레이터 저소음 선풍기 LZEF-AR03 49,800원 스마일배송
# 부토 전기찜기 계란찜기 간편세척 NBE622W 다용도찜기 22,900원 스마일배송
# [대우]대우 에어 써큘레이터DEF-KC1020스탠드선풍기 공기순환 35,900원 스마일배송
# [갤럭시]갤럭시S22울트라 5G 512GB 자급제 SM-S908N 1,442,800원 삼성모바일공식스토어
# [다이슨](최종55만원대) 본사 다이슨 에어랩 스타일러 볼륨 앤 쉐이프 + 스탠드 라운드 브러시 증정 571,330원 다이슨코리아유한회사
# [삼성전자]삼성 갤럭시 워치4 40mm 카드할인7%+필름 203,840원 삼성디지탈파크
# [기가바이트]A5 K1 R5 특가89만 라이젠 R5-5600H/16GB/512GB/RTX3060/FHD 144Hz/300nit 가성비 게이밍 노트북 1,078,000원 기가바이트공식총판
# [삼성전자]갤럭시 A53 5G SM-A536N 128G 자급제 _RM 495,430원 주식회사리플레이
# Hulmay 초음파 가정용 셀프 구강청결기 자동 39,920원 Mqglobal
# [비스포크](최대혜택가 53만원대) 삼성 비스포크 제트 무선청소기 220W VS20B956AXE 629,560원 삼성공식판매보보
# [대웅모닝컴](행사) 대웅모닝컴 14형 스탠드 선풍기 (신제품 입고) 29,900원 스마일배송
# [솔러스에어]1+1 2개 무선 선풍기 탁상용 미니 휴대용 캠핑용 벽걸이 사무실 선물용 가정용 59,900원 스마일배송
# [신일전자]신일 기본형 선풍기 ---10% 다운로드 쿠폰--- 59,900원 SHINIL
# ...

# %% [markdown]
# #### 지마켓 베스트 페이지 상품명 가격 + 이중 크로링으로 배송사 알아내기 선생님버전

# %%
import requests
from bs4 import BeautifulSoup

res = requests.get('http://corners.gmarket.co.kr/Bestsellers?viewType=G&groupCode=G06')
soup = BeautifulSoup(res.content, 'html.parser')
bestlists = soup.select('div.best-list')
bestitems = bestlists[0]
products = bestitems.select('ul > li')

for index, product in enumerate(products):
    title = product.select_one('a.itemname')
    price = product.select_one('div.s-price > strong')
    res_info = requests.get(title['href'])
    soup_info = BeautifulSoup(res_info.content, 'html.parser')
    provider_info = soup_info.select_one("div.item-topinfo_headline span.text__seller > a")

    print (title.get_text(), price.get_text(), provider_info.get_text())
#print (title.get_text(), price.get_text(), title['href'], provider_info.get_text())
# Out:
# [레노버]최종가:171,300원 레노버 T1SPRO 클린스테이션 청소기 유럽버전 202,000원 직구플리즈
# [갤럭시]갤럭시S22 5G 256GB 자급제 SM-S901N 930,150원 삼성모바일공식스토어
# [유파]내일도착유파 선풍기리모컨초미풍발터치 TSK-3528CR 29,900원 CJ온스타일
# [르젠]르젠 리모컨 써큘레이터 저소음 선풍기 LZEF-AR03 49,800원 스마일배송
# 부토 전기찜기 계란찜기 간편세척 NBE622W 다용도찜기 22,900원 스마일배송
# [대우]대우 에어 써큘레이터DEF-KC1020스탠드선풍기 공기순환 35,900원 스마일배송
# [갤럭시]갤럭시S22울트라 5G 512GB 자급제 SM-S908N 1,442,800원 삼성모바일공식스토어
# [다이슨](최종55만원대) 본사 다이슨 에어랩 스타일러 볼륨 앤 쉐이프 + 스탠드 라운드 브러시 증정 571,330원 다이슨코리아유한회사
# [삼성전자]삼성 갤럭시 워치4 40mm 카드할인7%+필름 203,840원 삼성디지탈파크
# [기가바이트]A5 K1 R5 특가89만 라이젠 R5-5600H/16GB/512GB/RTX3060/FHD 144Hz/300nit 가성비 게이밍 노트북 1,078,000원 기가바이트공식총판
# Hulmay 초음파 가정용 셀프 구강청결기 자동 39,920원 Mqglobal
# [삼성전자]갤럭시 A53 5G SM-A536N 128G 자급제 _RM 495,430원 주식회사리플레이
# [비스포크](최대혜택가 53만원대) 삼성 비스포크 제트 무선청소기 220W VS20B956AXE 629,560원 삼성공식판매보보
# [대웅모닝컴](행사) 대웅모닝컴 14형 스탠드 선풍기 (신제품 입고) 29,900원 스마일배송
# [솔러스에어]1+1 2개 무선 선풍기 탁상용 미니 휴대용 캠핑용 벽걸이 사무실 선물용 가정용 59,900원 스마일배송
# [신일전자]신일 기본형 선풍기 ---10% 다운로드 쿠폰--- 59,900원 SHINIL
# ...

# %% [markdown]
# ### 지마켓 토마호크 검색결과 크롤링

# %%
import requests
from bs4 import BeautifulSoup
import re

res = requests.get('http://browse.gmarket.co.kr/search?keyword=%ED%86%A0%EB%A7%88%ED%98%B8%ED%81%AC')
soup = BeautifulSoup(res.content, 'html.parser')
bestlists = soup.select('div.box__information-major')




for index,item in enumerate(bestlists):
    p_name= item.select_one('div.box__item-title > span > a > span.text__item')
    p_price= item.select_one('div.box__item-price > div.box__price-seller > strong')




    print(p_name.get_text(),p_price.get_text())
# Out:
#  고급진시즈닝 토마호크 스테이크 (냉동 초이스) 500g + 와사비버터증정  45,000
#  드라이에이징 국내산 삼겹살 500g 한돈 캠핑 돼지고기  24,900
#  드라이에이징 프라임 살치살 500g 스테이크 숙성 꽃살  65,500
#  드라이에이징 티본 500g내외 숙성소고기 스테이크 T본  49,900
#  드라이에이징 척아이롤 500g 프라임등심 소고기미국산  33,500
#  킹토마호크 스테이크 5cm 립아이 초이스 1kg  75,050
#  킹토마호크 스테이크 5cm 립아이 초이스 1150g~1200g  86,450
#  킹토마호크 스테이크 5cm 립아이 초이스 1050g~1100g  78,850
#  킹토마호크 스테이크 5cm 립아이 초이스 1100g~1150g  82,650
#  토마호크 스테이크 3cm 립아이 초이스 750g~800g  56,050
#  블랙앵거스 미국산 캠핑 스테이크 토마호크 5cm 1500g  112,500
#  블랙앵거스 미국산 캠핑 스테이크 토마호크 650g  48,750
#  토마호크 접이식 예초기안전날 1세트 벌초 풀베기 제초 안전날 관절날  49,800
#  갓성비 B급 리얼 토마호크 스테이크 1350g 초이스등급  59,200
#  토마호크 티본 스테이크 총 1kg  63,900
#  (현대Hmall) 바라던  본인립아이 토마호크 550g x 2팩 / 미국 초이스등급  76,900
#  프레시미트  블랙앵거스 토마호크 700g x 2  127,900
#  PRIME 냉장양갈비 램왕숄더랙 300g(호주산) +100g추가  13,200
#  해밀농장  우리한돈 1등급 함초 돈마호크 900g내외  31,900
#  앵거스 초이스 본인립아이 토마호크 550g  39,900
#  앵거스 초이스 본인립아이 토마호크 450g  34,900
#   글래드호텔  자연방목 램 토마호크 3팩 (총 1.5kg) + 양꼬치 1팩 (400g) + 허브시즈닝4팩 + 쯔란4팩  80,700
# ...

# %%
지마켓 베스트 식품 코너 랭킹+상품명 + 가격

# %%
import requests
from bs4 import BeautifulSoup
import re
res = requests.get('http://corners.gmarket.co.kr/Bestsellers?viewType=G&groupCode=G07')

soup=BeautifulSoup(res.content, 'html.parser')
bestlists=soup.select('div.best-list')
bestitmes= bestlists[0]
bestitem= bestitmes.select('ul> li')

for item in bestitem:
    rank=item.select_one('p')
    name= item.select_one('a.itemname')
    price= item.select_one('div.s-price > strong')
    print(rank.get_text(),name.get_text(), price.get_text(),name['href'])
# Out:
# 1 [롯데칠성]펩시콜라 제로 500mlx20펫 (무바코드)/쿠폰가 13110원 15,900원 http://item.gmarket.co.kr/Item?goodscode=2362208904&ver=637941010652141840
# 2 [참도깨비]금강만두 육개장 630g x5봉/ 쿠폰17620원/ 팩당 3500원 21,400원 http://item.gmarket.co.kr/Item?goodscode=2122330900&ver=637941010652141840
# 3 [정직한밥상]우거지 등뼈 감자탕 4.7kg10인분 쿠폰특가25900원 33,900원 http://item.gmarket.co.kr/Item?goodscode=1617175326&ver=637941010652141840
# 4 젓갈대전 3종세트 모음전 G11510 (오징어젓갈/비빔낙지/비빔오징어/갈치속젓/무말랭이) 12,900원 http://item.gmarket.co.kr/Item?goodscode=2503923214&ver=637941010652141840
# 5 [올반키친]올반 찰핫도그 80g X 30봉 아이가 좋아하는 흔한남매 26,700원 http://item.gmarket.co.kr/Item?goodscode=2237053510&ver=637941010652141840
# 6 [Gfresh]미스타셰프 육개장 600g 4팩/2+1증정 12,400원 http://item.gmarket.co.kr/Item?goodscode=2041518949&ver=637941010652141840
# 7 [Gfresh]산과들에 간식 견과류 허니버터아몬드18g x30봉 13,900원 http://item.gmarket.co.kr/Item?goodscode=2151827341&ver=637941010652141840
# ...
