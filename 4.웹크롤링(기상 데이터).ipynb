# %%
import requests
from bs4 import BeautifulSoup

import pandas as pd

# %%
res = requests.get('https://www.weather.go.kr/w/obs-climate/land/city-obs.do')
print(res)
# Out:
# <Response [200]>

# %%
soup=BeautifulSoup(res.content, 'html.parser')
soup
# Out:
# <!DOCTYPE html>
#
# <html lang="ko">
# <head>
# <title>도시별관측 - 기상청 날씨누리</title>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1.0, minimum-scale=1.0, user-scalable=yes" name="viewport"/>
# <meta content="telephone=no" name="format-detection"/>
# <link href="/w/iphone-shortcut.png" rel="shortcut icon"/>
# <link href="/w/iphone-shortcut.png" rel="apple-touch-icon-precomposed"/>
# <meta content="IE=Edge" http-equiv="X-UA-Compatible"/>
# <meta content="https://www.weather.go.kr/w/iphone-shortcut.png" property="og:image"/>
# <link href="/w/resources/css-2021/slick.css?ver=2022080901" rel="stylesheet" type="text/css"/>
# <link href="/w/resources/css-2021/basic.css?ver=2022080901" rel="stylesheet" type="text/css"/>
# <link href="/w/resources/css-2021/common-ui.css?ver=2022080901" rel="stylesheet" type="text/css"/>
# <link href="/w/resources/css-2021/common-ui-mobile.css?ver=2022080901" rel="stylesheet" type="text/css"/>
# ...

# %%
table =soup.find('table',{'class':'table-col'})



data=[]
for tr in table.find_all('tr'):
    tds = list(tr.find_all('td'))


    for td in tds:
           if td.find('a'):
               point=td.find('a').text
               tem=tds[5].text
               hu=tds[9].text
               data.append([point, tem, hu])
data
# Out:
# [['강릉', '23.0', '74'],
#  ['강진군', '26.8', '66'],
#  ['강화', '21.8', '73'],
#  ['거제', '26.3', '68'],
#  ['거창', '21.1', '82'],
#  ['경주시', '23.7', '79'],
#  ['고산', '27.4', '80'],
#  ['고창', '23.6', '72'],
#  ['고창군', '23.6', '72'],
#  ['고흥', '25.8', '65'],
#  ['광양시', '25.1', '67'],
#  ['광주', '22.8', '90'],
#  ['구미', '20.4', '87'],
#  ['군산', '20.0', '85'],
#  ['금산', '19.8', '89'],
#  ['김해시', '24.6', '76'],
#  ['남원', '22.2', '72'],
#  ['남해', '25.4', '68'],
#  ['대관령', '15.5', '85'],
#  ['대구', '22.9', '82'],
#  ['대전', '19.1', '89'],
#  ['동두천', '20.7', '77'],
#  ['동해', '21.2', '87'],
#  ['목포', '25.2', '71'],
#  ['문경', '19.8', '93'],
#  ['밀양', '25.1', '65'],
#  ['백령도', '17.6', '94'],
#  ['보령', '20.3', '75'],
#  ['보성군', '25.8', '72'],
#  ['보은', '18.4', '92'],
#  ['봉화', '17.7', '90'],
#  ['부산', '26.1', '71'],
#  ['부안', '22.3', '81'],
#  ['부여', '19.0', '93'],
#  ['북강릉', '21.3', '74'],
#  ['북창원', '25.5', '71'],
#  ['북춘천', '21.6', '73'],
#  ['산청', '22.1', '79'],
#  ['상주', '18.3', '93'],
# ...

# %%
data= pd.DataFrame(data)
data
# Out:
#     지역
# 0  NaN
# 1  NaN
# 2  NaN
# 3  NaN
# 4  NaN
# ..  ..
# 90 NaN
# 91 NaN
# 92 NaN
# 93 NaN
# 94 NaN
#
# [95 rows x 1 columns]

# %%
#while sum == 215:
url = 'https://finance.naver.com/item/frgn.naver?code=036030&page=1'
df= pd.read_html(requests.get(url, headers = {'User-agent' : 'Mozilla/5.0'}).text)
df[2]
# Out:
#             날짜      종가    전일비     등락률       거래량     기관      외국인            \
#             날짜      종가    전일비     등락률       거래량   순매매량     순매매량      보유주수
# 0          NaN     NaN    NaN     NaN       NaN    NaN      NaN       NaN
# 1   2022.08.26  6270.0   40.0  -0.63%   55571.0    0.0   3382.0  452389.0
# 2   2022.08.25  6310.0  140.0  +2.27%   55898.0   -3.0   7044.0  449007.0
# 3   2022.08.24  6170.0    0.0   0.00%   48557.0  159.0   3296.0  441963.0
# 4   2022.08.23  6170.0  110.0  -1.75%   61745.0    4.0  -7431.0  438667.0
# 5   2022.08.22  6280.0  270.0  -4.12%  143232.0    4.0  -9530.0  446098.0
# 6          NaN     NaN    NaN     NaN       NaN    NaN      NaN       NaN
# 7          NaN     NaN    NaN     NaN       NaN    NaN      NaN       NaN
# 8          NaN     NaN    NaN     NaN       NaN    NaN      NaN       NaN
# 9   2022.08.19  6550.0   90.0  -1.36%  134290.0    7.0   2512.0  455628.0
# 10  2022.08.18  6640.0   50.0  -0.75%  139267.0   -1.0 -11060.0  453116.0
# ...

# %%
#웹크롤링으로 데이터 가져와서
#리스트를 데이터프레임으로 만들고
#non값 전처리 과정으로 전처리  완료
url = 'https://finance.naver.com/item/frgn.naver?code=036030&page=2'
df= pd.read_html(requests.get(url, headers = {'User-agent' : 'Mozilla/5.0'}).text)
df2=df[2]
df_jusic= pd.DataFrame(df2)
df_jusic
df_jusic= df_jusic.dropna(axis=0)
df_jusic
# Out:
#             날짜      종가    전일비     등락률      거래량    기관      외국인
#             날짜      종가    전일비     등락률      거래량  순매매량     순매매량      보유주수    보유율
# 1   2022.06.15  5440.0  190.0  -3.37%  52283.0   0.0  -9180.0  478641.0  0.98%
# 2   2022.06.14  5630.0  220.0  -3.76%  81524.0   0.0   1739.0  487821.0  1.00%
# 3   2022.06.13  5850.0  320.0  -5.19%  77012.0   0.0 -10667.0  486082.0  0.99%
# 4   2022.06.10  6170.0   30.0  -0.48%  18193.0  -1.0  -4646.0  496749.0  1.01%
# 5   2022.06.09  6200.0   40.0  -0.64%  16471.0  -2.0  -4420.0  501395.0  1.02%
# 9   2022.06.08  6240.0   10.0  -0.16%  25285.0  -2.0  -3866.0  505815.0  1.03%
# 10  2022.06.07  6250.0   60.0  -0.95%  26704.0  -3.0  -1674.0  509681.0  1.04%
# 11  2022.06.03  6310.0  100.0  +1.61%  36675.0  -4.0   6306.0  511355.0  1.04%
# 12  2022.06.02  6210.0   50.0  -0.80%  19764.0  -7.0   1302.0  505049.0  1.03%
# 13  2022.05.31  6260.0   20.0  +0.32%  36016.0   0.0   6370.0  503747.0  1.03%
# ...

# %%
#두개의 데이터를 concat으로 테스ㅡ트 해보았다
#잘댐  인덱스 세팅주의
jusic_copy1= pd.DataFrame(df_jusic)
jusic_copy2= pd.DataFrame(df_jusic)
cocat_jusic= pd.concat([jusic_copy1,jusic_copy2], ignore_index=True)
cocat_jusic
# Out:
#             날짜      종가    전일비     등락률      거래량    기관      외국인
#             날짜      종가    전일비     등락률      거래량  순매매량     순매매량      보유주수    보유율
# 0   2022.06.15  5440.0  190.0  -3.37%  52283.0   0.0  -9180.0  478641.0  0.98%
# 1   2022.06.14  5630.0  220.0  -3.76%  81524.0   0.0   1739.0  487821.0  1.00%
# 2   2022.06.13  5850.0  320.0  -5.19%  77012.0   0.0 -10667.0  486082.0  0.99%
# 3   2022.06.10  6170.0   30.0  -0.48%  18193.0  -1.0  -4646.0  496749.0  1.01%
# 4   2022.06.09  6200.0   40.0  -0.64%  16471.0  -2.0  -4420.0  501395.0  1.02%
# 5   2022.06.08  6240.0   10.0  -0.16%  25285.0  -2.0  -3866.0  505815.0  1.03%
# 6   2022.06.07  6250.0   60.0  -0.95%  26704.0  -3.0  -1674.0  509681.0  1.04%
# 7   2022.06.03  6310.0  100.0  +1.61%  36675.0  -4.0   6306.0  511355.0  1.04%
# 8   2022.06.02  6210.0   50.0  -0.80%  19764.0  -7.0   1302.0  505049.0  1.03%
# 9   2022.05.31  6260.0   20.0  +0.32%  36016.0   0.0   6370.0  503747.0  1.03%
# ...

# %%
# for문으로 페이지 반복



url_test = 'https://finance.naver.com/item/frgn.naver?code=036030&page={}'
df_test= pd.read_html(requests.get(url_test, headers = {'User-agent' : 'Mozilla/5.0'}).text)

    url= url_test.format(i)
df


#df2_test=df_test[2]
#df_jusic_test= pd.DataFrame(df2_test)
#df_jusic_test_drop= df_jusic_test.dropna(axis=0)
#df_jusic_test_drop
